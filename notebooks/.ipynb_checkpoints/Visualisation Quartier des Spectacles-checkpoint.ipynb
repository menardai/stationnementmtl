# %% [markdown]
# # Quartier des Spectacles

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
qds1516 = pd.read_csv('../TxOccupation_QDS_2015et16.csv', sep=';', decimal=",")

# %% [markdown]
# # Get a first look

# %%
qds1516.head()
# Out:
#    NoTroncon                                 DescriptionTroncon DateCreation  \
# 0          1  Bleury entre Sherbrooke et Président-Kennedy -...   2015-01-01
# 1          1  Bleury entre Sherbrooke et Président-Kennedy -...   2015-01-01
# 2          1  Bleury entre Sherbrooke et Président-Kennedy -...   2015-01-01
# 3          1  Bleury entre Sherbrooke et Président-Kennedy -...   2015-01-01
# 4          1  Bleury entre Sherbrooke et Président-Kennedy -...   2015-01-01
#
#    NoHeure  NbMinDispo  TxOccupation
# 0        9           0           0.0
# 1       10           0           0.0
# 2       11           0           0.0
# 3       12           0           0.0
# 4       13           0           0.0

# %%
# number of rows
len(qds1516)
# Out:
# 1186356

# %% [markdown]
# # Remove columns, change data types

# %%
# remove some columns
qds1516.drop('DescriptionTroncon', 1, inplace=True)

# %%
# convert NoHeure and NoTroncon columns from int to category
qds1516.NoHeure = qds1516.NoHeure.astype('category')
qds1516.NoTroncon = qds1516.NoTroncon.astype('category')

# %%
# convert DateCreation from Object to Date
qds1516.DateCreation = pd.to_datetime(qds1516['DateCreation'])

# %% [markdown]
# ---

# %%
qds1516.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186356 entries, 0 to 1186355
# Data columns (total 5 columns):
# NoTroncon       1186356 non-null category
# DateCreation    1186356 non-null datetime64[ns]
# NoHeure         1186356 non-null category
# NbMinDispo      1186356 non-null int64
# TxOccupation    1186356 non-null float64
# dtypes: category(2), datetime64[ns](1), float64(1), int64(1)
# memory usage: 30.6 MB

# %% [markdown]
# # Removing rows with 0 occupancy rate
# these row are probably errors or the street has been closed

# %%
#qds1516 = troncon402[troncon402['TxOccupation'] > 0]

# %%
qds1516.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186356 entries, 0 to 1186355
# Data columns (total 5 columns):
# NoTroncon       1186356 non-null category
# DateCreation    1186356 non-null datetime64[ns]
# NoHeure         1186356 non-null category
# NbMinDispo      1186356 non-null int64
# TxOccupation    1186356 non-null float64
# dtypes: category(2), datetime64[ns](1), float64(1), int64(1)
# memory usage: 30.6 MB

# %% [markdown]
# ---

# %%
# get stats on the columns
qds1516.describe()
# Out:
#          NbMinDispo  TxOccupation
# count  1.186356e+06  1.186356e+06
# mean   5.944760e+02  4.145478e-01
# std    3.957266e+02  3.555239e-01
# min    0.000000e+00  0.000000e+00
# 25%    3.000000e+02  1.670000e-02
# 50%    4.800000e+02  3.762000e-01
# 75%    8.400000e+02  7.333000e-01
# max    2.280000e+03  1.000000e+00

# %%
qds1516.tail()
# Out:
#         NoTroncon DateCreation NoHeure  NbMinDispo  TxOccupation
# 1186351      2919   2016-12-31      13         120           0.0
# 1186352      2919   2016-12-31      14         120           0.0
# 1186353      2919   2016-12-31      15         120           0.0
# 1186354      2919   2016-12-31      16         120           0.0
# 1186355      2919   2016-12-31      17         120           0.0

# %% [markdown]
# ---

# %% [markdown]
# # Add a column: Day of Week

# %%
qds1516['DayOfWeek'] = qds1516['DateCreation'].dt.dayofweek

# %%
days = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}

qds1516['DayOfWeek'] = qds1516['DayOfWeek'].apply(lambda x: days[x])

# %%
qds1516[100000:100002]
# Out:
#        NoTroncon DateCreation NoHeure  NbMinDispo  TxOccupation DayOfWeek
# 100000        21   2016-08-18      10         480        0.8333  Thursday
# 100001        21   2016-08-18      11         480        0.7979  Thursday

# %% [markdown]
# ---

# %% [markdown]
# # Add a column: Day of Year

# %%
qds1516['DayOfYear'] = qds1516['DateCreation'].dt.dayofyear

# %%
qds1516[0:2]
# Out:
#   NoTroncon DateCreation NoHeure  NbMinDispo  TxOccupation DayOfWeek  \
# 0         1   2015-01-01       9           0           0.0  Thursday
# 1         1   2015-01-01      10           0           0.0  Thursday
#
#    DayOfYear
# 0          1
# 1          1

# %%
qds1516[100000:100002]
# Out:
#        NoTroncon DateCreation NoHeure  NbMinDispo  TxOccupation DayOfWeek  \
# 100000        21   2016-08-18      10         480        0.8333  Thursday
# 100001        21   2016-08-18      11         480        0.7979  Thursday
#
#         DayOfYear
# 100000        231
# 100001        231

# %% [markdown]
# ---

# %% [markdown]
# # 25 novembre 2015

# %%
OneDay = qds1516[ (qds1516['DateCreation'] == '2015-11-25') ]

# %%
OneDay
# Out:
#         NoTroncon DateCreation NoHeure  NbMinDispo  TxOccupation  DayOfWeek
# 3513            1   2015-11-25       9        1020        0.6824  Wednesday
# 3514            1   2015-11-25      10        1020        0.9627  Wednesday
# 3515            1   2015-11-25      11        1020        1.0000  Wednesday
# 3516            1   2015-11-25      12        1020        0.7304  Wednesday
# 3517            1   2015-11-25      13        1020        0.8765  Wednesday
# 3518            1   2015-11-25      14        1020        0.7971  Wednesday
# 3519            1   2015-11-25      15        1020        0.7098  Wednesday
# 3520            1   2015-11-25      16        1020        0.5588  Wednesday
# 3521            1   2015-11-25      17        1020        0.3873  Wednesday
# 3522            1   2015-11-25      18        1020        0.8873  Wednesday
# 3523            1   2015-11-25      19        1020        1.0000  Wednesday
# 3524            1   2015-11-25      20        1020        1.0000  Wednesday
# 11329           2   2015-11-25       9         300        0.2933  Wednesday
# 11330           2   2015-11-25      10         600        0.9483  Wednesday
# 11331           2   2015-11-25      11         600        1.0000  Wednesday
# 11332           2   2015-11-25      12         600        0.8033  Wednesday
# 11333           2   2015-11-25      13         600        0.9117  Wednesday
# 11334           2   2015-11-25      14         600        0.8183  Wednesday
# 11335           2   2015-11-25      15         600        0.6917  Wednesday
# 11336           2   2015-11-25      16         600        0.4600  Wednesday
# 11337           2   2015-11-25      17         600        0.2067  Wednesday
# 11338           2   2015-11-25      18         600        0.6750  Wednesday
# 11339           2   2015-11-25      19         600        0.8133  Wednesday
# 11340           2   2015-11-25      20         600        0.9150  Wednesday
# 19112           3   2015-11-25       9         360        0.1222  Wednesday
# 19113           3   2015-11-25      10         360        0.4111  Wednesday
# 19114           3   2015-11-25      11         360        0.7028  Wednesday
# 19115           3   2015-11-25      12         360        0.7306  Wednesday
# 19116           3   2015-11-25      13         360        0.8111  Wednesday
# 19117           3   2015-11-25      14         360        0.8472  Wednesday
# ...           ...          ...     ...         ...           ...        ...
# 1166574      2874   2015-11-25      15         180        0.1111  Wednesday
# 1166575      2874   2015-11-25      16         180        0.0000  Wednesday
# 1166576      2874   2015-11-25      17         180        0.0000  Wednesday
# 1166577      2874   2015-11-25      18         180        0.0889  Wednesday
# 1166578      2874   2015-11-25      19         180        0.6167  Wednesday
# 1166579      2874   2015-11-25      20         180        0.6667  Wednesday
# 1174328      2918   2015-11-25       9         180        0.1167  Wednesday
# 1174329      2918   2015-11-25      10         360        0.6694  Wednesday
# 1174330      2918   2015-11-25      11         360        1.0000  Wednesday
# 1174331      2918   2015-11-25      12         360        0.5861  Wednesday
# 1174332      2918   2015-11-25      13         360        0.9722  Wednesday
# 1174333      2918   2015-11-25      14         360        0.3389  Wednesday
# 1174334      2918   2015-11-25      15         360        0.2500  Wednesday
# 1174335      2918   2015-11-25      16         360        0.3500  Wednesday
# 1174336      2918   2015-11-25      17         360        0.5583  Wednesday
# 1174337      2918   2015-11-25      18         360        0.8528  Wednesday
# 1174338      2918   2015-11-25      19         360        0.9500  Wednesday
# 1174339      2918   2015-11-25      20         360        0.6500  Wednesday
# 1182089      2919   2015-11-25       9          60        0.0000  Wednesday
# 1182090      2919   2015-11-25      10         120        0.0000  Wednesday
# 1182091      2919   2015-11-25      11         120        0.0000  Wednesday
# 1182092      2919   2015-11-25      12         120        0.0000  Wednesday
# 1182093      2919   2015-11-25      13         120        0.0000  Wednesday
# 1182094      2919   2015-11-25      14         120        0.0000  Wednesday
# 1182095      2919   2015-11-25      15         120        0.0000  Wednesday
# 1182096      2919   2015-11-25      16         120        0.0000  Wednesday
# 1182097      2919   2015-11-25      17         120        0.4667  Wednesday
# 1182098      2919   2015-11-25      18         120        0.5000  Wednesday
# 1182099      2919   2015-11-25      19         120        0.5000  Wednesday
# 1182100      2919   2015-11-25      20         120        0.3250  Wednesday
#
# [1845 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Print number of unique troncon

# %%
no_section_list = qds1516.NoTroncon.unique()

# %%
len(no_section_list)
# Out:
# 161

# %%
print(no_section_list)
# Out:
# [1, 2, 3, 4, 5, ..., 2781, 2821, 2874, 2918, 2919]
# Length: 161
# Categories (161, int64): [1, 2, 3, 4, ..., 2821, 2874, 2918, 2919]

# %% [markdown]
# ---

# %% [markdown]
# # Extract a specific section

# %%
troncon402 = qds1516[qds1516['NoTroncon'] == 402]

# %%
troncon402.head()
# Out:
#        NoTroncon DateCreation NoHeure  NbMinDispo  TxOccupation DayOfWeek
# 274112       402   2015-01-01      15           0           0.0  Thursday
# 274113       402   2015-01-01      16           0           0.0  Thursday
# 274114       402   2015-01-01      17           0           0.0  Thursday
# 274115       402   2015-01-01      18           0           0.0  Thursday
# 274116       402   2015-01-01      19           0           0.0  Thursday

# %%
troncon402.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7916 entries, 274112 to 282027
# Data columns (total 6 columns):
# NoTroncon       7916 non-null category
# DateCreation    7916 non-null datetime64[ns]
# NoHeure         7916 non-null category
# NbMinDispo      7916 non-null int64
# TxOccupation    7916 non-null float64
# DayOfWeek       7916 non-null object
# dtypes: category(2), datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 339.1+ KB
